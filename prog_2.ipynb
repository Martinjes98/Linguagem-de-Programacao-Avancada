# %%
import pandas

# %%
import pandas as pd

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
director = pd.read_csv('dadus_foun/x.csv')

# %%
director.head(20)
# Out:
#         director_name                                             genres  \
# 0       James Cameron                    Action|Adventure|Fantasy|Sci-Fi
# 1      Gore Verbinski                           Action|Adventure|Fantasy
# 2          Sam Mendes                          Action|Adventure|Thriller
# 3   Christopher Nolan                                    Action|Thriller
# 4         Doug Walker                                        Documentary
# 5      Andrew Stanton                            Action|Adventure|Sci-Fi
# 6           Sam Raimi                           Action|Adventure|Romance
# 7        Nathan Greno  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8         Joss Whedon                            Action|Adventure|Sci-Fi
# 9         David Yates                   Adventure|Family|Fantasy|Mystery
# 10        Zack Snyder                            Action|Adventure|Sci-Fi
# 11       Bryan Singer                            Action|Adventure|Sci-Fi
# ...

# %%
director.shape
# Out:
# (4916, 3)

# %%
director.head(10)
# Out:
#        director_name                                             genres  color
# 0      James Cameron                    Action|Adventure|Fantasy|Sci-Fi  Color
# 1     Gore Verbinski                           Action|Adventure|Fantasy  Color
# 2         Sam Mendes                          Action|Adventure|Thriller  Color
# 3  Christopher Nolan                                    Action|Thriller  Color
# 4        Doug Walker                                        Documentary    NaN
# 5     Andrew Stanton                            Action|Adventure|Sci-Fi  Color
# 6          Sam Raimi                           Action|Adventure|Romance  Color
# 7       Nathan Greno  Adventure|Animation|Comedy|Family|Fantasy|Musi...  Color
# 8        Joss Whedon                            Action|Adventure|Sci-Fi  Color
# 9        David Yates                   Adventure|Family|Fantasy|Mystery  Color

# %%
director.dropna(inplace=True)

# %%
director.head(200)
# Out:
#              director_name                                             genres  \
# 0            James Cameron                    Action|Adventure|Fantasy|Sci-Fi
# 1           Gore Verbinski                           Action|Adventure|Fantasy
# 2               Sam Mendes                          Action|Adventure|Thriller
# 3        Christopher Nolan                                    Action|Thriller
# 5           Andrew Stanton                            Action|Adventure|Sci-Fi
# 6                Sam Raimi                           Action|Adventure|Romance
# 7             Nathan Greno  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8              Joss Whedon                            Action|Adventure|Sci-Fi
# 9              David Yates                   Adventure|Family|Fantasy|Mystery
# 10             Zack Snyder                            Action|Adventure|Sci-Fi
# 11            Bryan Singer                            Action|Adventure|Sci-Fi
# ...

# %%
director
# Out:
#            director_name                                             genres  \
# 0          James Cameron                    Action|Adventure|Fantasy|Sci-Fi
# 1         Gore Verbinski                           Action|Adventure|Fantasy
# 2             Sam Mendes                          Action|Adventure|Thriller
# 3      Christopher Nolan                                    Action|Thriller
# 5         Andrew Stanton                            Action|Adventure|Sci-Fi
# 6              Sam Raimi                           Action|Adventure|Romance
# 7           Nathan Greno  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8            Joss Whedon                            Action|Adventure|Sci-Fi
# 9            David Yates                   Adventure|Family|Fantasy|Mystery
# 10           Zack Snyder                            Action|Adventure|Sci-Fi
# 11          Bryan Singer                            Action|Adventure|Sci-Fi
# ...

# %%
director.shape
# Out:
# (4797, 3)
