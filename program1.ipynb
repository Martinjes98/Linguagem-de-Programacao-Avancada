# %% [markdown]
# # import Library

# %% [markdown]
# # mai ita aprende pandas

# %%
import pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
movie = pd.read_csv('movie.csv')
movie.head(20)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 4     NaN        Doug Walker                     NaN       NaN
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
# 11  Color       Bryan Singer                   434.0     169.0
# 12  Color       Marc Forster                   403.0     106.0
# 13  Color     Gore Verbinski                   313.0     151.0
# ...

# %%
movie.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  \
# 4911                   637.0      NaN                  Comedy|Drama
# ...

# %%
movie.shape
# Out:
# (4916, 28)

# %%
movie.count()
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %%
movie.director_name
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
movie['director_name']
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
direct = movie.director_name
direct.head()
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
movie.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
movie['director_name','direct.head()']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('director_name', 'direct.head()')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-d242077f8cdb> in <module>
# ...

# %%
movie[['director_name','genres','color']]
# Out:
#            director_name                                             genres  \
# 0          James Cameron                    Action|Adventure|Fantasy|Sci-Fi
# 1         Gore Verbinski                           Action|Adventure|Fantasy
# 2             Sam Mendes                          Action|Adventure|Thriller
# 3      Christopher Nolan                                    Action|Thriller
# 4            Doug Walker                                        Documentary
# 5         Andrew Stanton                            Action|Adventure|Sci-Fi
# 6              Sam Raimi                           Action|Adventure|Romance
# 7           Nathan Greno  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8            Joss Whedon                            Action|Adventure|Sci-Fi
# 9            David Yates                   Adventure|Family|Fantasy|Mystery
# 10           Zack Snyder                            Action|Adventure|Sci-Fi
# ...

# %%
movie[['director_name','genres','color']]
# Out:
#            director_name                                             genres  \
# 0          James Cameron                    Action|Adventure|Fantasy|Sci-Fi
# 1         Gore Verbinski                           Action|Adventure|Fantasy
# 2             Sam Mendes                          Action|Adventure|Thriller
# 3      Christopher Nolan                                    Action|Thriller
# 4            Doug Walker                                        Documentary
# 5         Andrew Stanton                            Action|Adventure|Sci-Fi
# 6              Sam Raimi                           Action|Adventure|Romance
# 7           Nathan Greno  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8            Joss Whedon                            Action|Adventure|Sci-Fi
# 9            David Yates                   Adventure|Family|Fantasy|Mystery
# 10           Zack Snyder                            Action|Adventure|Sci-Fi
# ...

# %%
x = movie[['director_name','genres','color']]

# %%
x
# Out:
#            director_name                                             genres  \
# 0          James Cameron                    Action|Adventure|Fantasy|Sci-Fi
# 1         Gore Verbinski                           Action|Adventure|Fantasy
# 2             Sam Mendes                          Action|Adventure|Thriller
# 3      Christopher Nolan                                    Action|Thriller
# 4            Doug Walker                                        Documentary
# 5         Andrew Stanton                            Action|Adventure|Sci-Fi
# 6              Sam Raimi                           Action|Adventure|Romance
# 7           Nathan Greno  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8            Joss Whedon                            Action|Adventure|Sci-Fi
# 9            David Yates                   Adventure|Family|Fantasy|Mystery
# 10           Zack Snyder                            Action|Adventure|Sci-Fi
# ...

# %%
x.to_csv('x.csv',index = False)

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
# color                        4897 non-null object
# director_name                4814 non-null object
# num_critic_for_reviews       4867 non-null float64
# duration                     4901 non-null float64
# director_facebook_likes      4814 non-null float64
# actor_3_facebook_likes       4893 non-null float64
# actor_2_name                 4903 non-null object
# actor_1_facebook_likes       4909 non-null float64
# gross                        4054 non-null float64
# genres                       4916 non-null object
# actor_1_name                 4909 non-null object
# movie_title                  4916 non-null object
# num_voted_users              4916 non-null int64
# cast_total_facebook_likes    4916 non-null int64
# actor_3_name                 4893 non-null object
# facenumber_in_poster         4903 non-null float64
# ...

# %% [markdown]
# range

# %%
print(movie['gross'].max() - movie['gross'].min())

# %% [markdown]
# variance

# %%
print(movie['gross'].var())

# %% [markdown]
# standard derivation

# %%
print(movie['gross'].std)
# Out:
# <bound method Series.std of 0       760505847.0
# 1       309404152.0
# 2       200074175.0
# 3       448130642.0
# 4               NaN
# 5        73058679.0
# 6       336530303.0
# 7       200807262.0
# 8       458991599.0
# 9       301956980.0
# 10      330249062.0
# 11      200069408.0
# 12      168368427.0
# 13      423032628.0
# 14       89289910.0
# 15      291021565.0
# 16      141614023.0
# 17      623279547.0
# 18      241063875.0
# 19      179020854.0
# 20      255108370.0
# 21      262030663.0
# 22      105219735.0
# 23      258355354.0
# 24       70083519.0
# 25      218051260.0
# 26      658672302.0
# 27      407197282.0
# 28       65173160.0
# 29      652177271.0
#            ...
# 4886            NaN
# 4887            NaN
# 4888      1227508.0
# 4889            NaN
# 4890            NaN
# 4891            NaN
# 4892            NaN
# 4893            NaN
# 4894       192467.0
# 4895            NaN
# 4896        76382.0
# 4897            NaN
# 4898       180483.0
# ...

# %%
print(movie.corr())
# Out:
#                            num_critic_for_reviews  duration  \
# num_critic_for_reviews                   1.000000  0.254602
# duration                                 0.254602  1.000000
# director_facebook_likes                  0.184647  0.175786
# actor_3_facebook_likes                   0.265420  0.120489
# actor_1_facebook_likes                   0.187637  0.087040
# gross                                    0.470873  0.243436
# num_voted_users                          0.623081  0.311628
# cast_total_facebook_likes                0.258970  0.120612
# facenumber_in_poster                    -0.032038  0.015309
# num_user_for_reviews                     0.605086  0.321956
# budget                                   0.192922  0.145981
# title_year                               0.276323 -0.140148
# actor_2_facebook_likes                   0.280032  0.130068
# imdb_score                               0.309733  0.264440
# aspect_ratio                            -0.051772 -0.091959
# ...

# %%
movie.corr()
# Out:
#                            num_critic_for_reviews  duration  \
# num_critic_for_reviews                   1.000000  0.254602
# duration                                 0.254602  1.000000
# director_facebook_likes                  0.184647  0.175786
# actor_3_facebook_likes                   0.265420  0.120489
# actor_1_facebook_likes                   0.187637  0.087040
# gross                                    0.470873  0.243436
# num_voted_users                          0.623081  0.311628
# cast_total_facebook_likes                0.258970  0.120612
# facenumber_in_poster                    -0.032038  0.015309
# num_user_for_reviews                     0.605086  0.321956
# budget                                   0.192922  0.145981
# title_year                               0.276323 -0.140148
# actor_2_facebook_likes                   0.280032  0.130068
# imdb_score                               0.309733  0.264440
# aspect_ratio                            -0.051772 -0.091959
# ...
